# %% [markdown]
# # Analysis of Generated text from two LLM ( ChatGPT, Deep Seek, Gemini)

# %% [markdown]
# In this analysis, we have focused on creative task of large language models. We have designed this analysis into four categories. And the asked questions are descibed as:
#
#     Creativity - Write a poem about space exploration.
#     Factual Accuracy - What are the benifits of renewable energy.
#     Open Minded - How would you design a futuristic city?

# %% [markdown]
# In the statistical Analysis Method, we also analyse them by five different parameters. These are:
#
#     Readability Score
#     Vocabulary Richness
#     Coherence and Similarity
#     Sentiment Analysis
#     Grammar and Error Detection

# %% [markdown]
# And the evaluation Methods are:
#
#     Criterion	Measurement Method
#     Readability	Flesch-Kincaid Readability Score, Dale-Chall Score
#     Lexical Richness	Type-Token Ratio (TTR), Vocabulary Diversity (MTLD)
#     Coherence	Cosine Similarity, Sentence Transition Scores
#     Sentiment	Sentiment Analysis (Positive/Negative Score)
#     Grammar/Errors	Grammar checking tools (e.g., Grammarly, LanguageTool)
#     Conciseness	Text length, Redundancy detection
#     Relevance	Topic Modeling (LDA, TF-IDF similarity)

# %% [markdown]
# ## Statistical Analysis

# %% [markdown]
# ## Importing all libraries

# %%
from textstat import flesch_reading_ease, dale_chall_readability_score
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from textblob import TextBlob
import language_tool_python

# %% [markdown]
# ## Creativity Analysis

# %%
text1_gpt = "Title: Red Horizons The Martian dust clung to every surface, a reminder that despite the technology that kept them alive, Mars was never going to be home. Yet, Commander Elara Voss stood at the observation window of Habitat 3, watching the twin moons Phobos and Deimos drift across the blood red sky. Commander, the terraforming array is ready for activation, reported Dr. Malik Chen, the lead scientist of the colony. Elara turned, her gaze steady.  We’ve spent a decade preparing for this moment. Let’s not waste it. With a nod, Malik activated the console. A deep hum resonated through the habitat as massive machines, scattered across the Martian surface, roared to life. The first wave of oxygen generators and atmospheric processors began their slow transformation of the planet. Hours passed. Data streamed in, showing minute changes in atmospheric composition. Then, the unexpected happened. Commander!  shouted Lieutenant Aria Kim.  We’re detecting an anomalous signal coming from Olympus Mons. Elara frowned.  Olympus Mons? There’s no equipment stationed there. Exactly, Aria replied.  But this signal… it’s not natural. The room fell silent. Assemble a team, Elara ordered.  We’re going to investigate.  The journey to Olympus Mons was perilous, but the team, clad in advanced EVA suits, navigated the treacherous terrain. As they approached the base of the colossal volcano, the signal grew stronger. Finally, they found it: a hidden entrance carved into the rock. This wasn’t made by us, Malik whispered. The team ventured inside, their lights piercing the darkness. What they found defied explanation. A vast chamber, illuminated by a soft, ethereal glow, housed advanced machinery beyond human comprehension. At its center, a holographic projection flickered to life, depicting a star map with Mars at its heart. A voice, ancient and resonant, echoed in their minds. Welcome, travelers. We have awaited your arrival. Mars was once our cradle, and now it shall be yours. Elara stepped forward, her heart pounding.  Who are you? We are the Architects, the first to walk this soil. Your coming was foretold, and now, our legacy is yours to continue. As the hologram faded, the machinery around them hummed to life, accelerating the terraforming process. Mars was no longer just a colony. It was a new beginning."
text2_deep = "Title:  Beneath the Rust The dust storm had raged for 37 hours. Outside the habitat’s reinforced plexiglass, the sky was a furious ochre haze. Inside, Commander Elara Voss stared at the blinking red alert on her wristpad: Oxygen reserves at 18%. Repair ECLSS immediately. The atmospheric processor’s buried under three meters of sand, growled Kael, their engineer, slamming his toolkit onto the lab table.  We’ll suffocate before we dig it out. Dr. Nia Tran, the mission’s biologist, didn’t look up from her microscope.  The lichen samples from Valles Marineris—they’re photosynthesizing. Weakly, but enough. If we redirect power to the growth lamps, they could offset the O₂ loss. They’re  lichen , Nia,  Kael snapped.  Not a miracle. Elara silenced them with a raised hand.  We do both. Kael, suit up—take Jax with you to dig out the processor. Nia, reconfigure the lab. Prioritize the lichen. Two hours later, Jax’s voice crackled over the comms.  Commander… you need to see this. Elara found them at the edge of the storm’s debris field. Kael knelt beside a jagged fissure in the Martian crust, his helmet light illuminating a glint of cobalt beneath the rust colored soil. Water ice, Jax whispered.  But that’s not all. Scan the sediment. Elara’s breath caught. Her visor display flagged organic compounds— amino acids. Back in the habitat, Nia’s hands trembled as she stabilized the sample.  It’s dormant… but alive. Single celled.  Native. The crew crowded around, their earlier tension dissolved in the glow of the discovery. Kael broke the silence.  So Mars wasn’t always a graveyard. Elara gazed at the tiny organisms on the screen, their membranes shimmering like opals.  And it doesn’t have to be one now. By dawn, the storm had passed. The lichen thrived under augmented lamps, and Kael jury rigged a pump to extract water from the ice. As the team gathered on the habitat’s observation deck, Elara opened a encrypted channel to Earth. Mission Control—we’re revising our priorities. Send the terraforming specs. And a bigger lab. Outside, the first human made oasis on Mars glowed green beneath a pink sky, while beneath their boots, a primordial whisper promised redemption. Life finds a way, Elara thought.  Even here. The End. Theme: Resilience and collaboration turn desolation into hope, bridging the ancient and the engineered."
text3_gemini = "The red dust swirled outside the biodome, a constant reminder of Mars's unforgiving nature. Inside, Anya tended her hydroponic garden, the vibrant green of Earth crops a stark contrast to the rusty landscape beyond. It had been five years since the Ares VI mission landed, five years since humanity established its first permanent foothold on Mars. Life on Mars was a delicate balance. Every breath, every drop of water, every calorie of food was meticulously managed, recycled, conserved. The dome was their world, a fragile bubble of life in an alien wilderness. Anya missed the rain, the smell of fresh earth, the vastness of a true sky. But she also felt a thrill, a sense of pioneering, of building a new home for humanity among the stars. One day, a tremor shook the dome, a low rumble that sent dust cascading from the artificial ceiling. The emergency lights flickered on, casting long, eerie shadows.  Seismic event, magnitude 4.2, a calm voice announced over the comm system.  All personnel, report to central hub. Fear gnawed at Anya. They had prepared for such events, but this was the strongest tremor yet. As she rushed to the hub, she couldn't help but wonder if their fragile bubble could withstand the planet's wrath. At the hub, the situation was tense. The tremor had damaged a section of the life support system, and oxygen levels were slowly dropping.  We need to repair the damage immediately, Commander Eva said, her voice firm but strained.  Anya, you're with the repair team. Suit up. Anya felt a surge of adrenaline. This was it, the moment of truth. She donned her EVA suit, the familiar hiss of oxygen filling her helmet. Outside the dome, the Martian landscape was bathed in the pale light of the twin moons, Phobos and Deimos. The stars, so clear and bright in the thin atmosphere, seemed to watch them, indifferent to their struggle. Working quickly, the repair team located the damaged section, a twisted mass of metal and wires. Anya's gloved hands worked deftly, replacing damaged components, sealing breaches. Time seemed to stretch and compress, each second a precious resource. Finally, after what felt like an eternity, the repair was complete. The life support system sputtered back to life, and a collective sigh of relief echoed through the comm system. Inside the dome, the oxygen levels stabilized, and the emergency lights dimmed. Exhausted but exhilarated, Anya returned to the dome. As she removed her helmet, she looked out at the Martian landscape, no longer a hostile wilderness, but a challenge overcome, a testament to human resilience. They had faced the red planet's fury and emerged stronger. Mars was still a harsh mistress, but it was also home, their home, a new frontier for humanity."

# %% [markdown]
# ### Readability Score
#
# Flesch-Kincaid Readability Test
#
#     Measures how easy a text is to read.
#     Higher score = easier readability.

# %%
print(f"Chat GPT Readability: {flesch_reading_ease(text1_gpt)}")
print(f"Deep Seek Readability: {flesch_reading_ease(text2_deep)}")
print(f"Gemini Readability: {flesch_reading_ease(text3_gemini)}")

#print(f"Chat GPT Dale-Chall Score: {dale_chall_readability_score(text1_gpt)}")
#print(f"Deep Seek Dale-Chall Score: {dale_chall_readability_score(text2_deep)}")
#print(f"Gemini Dale-Chall Score: {dale_chall_readability_score(text3_gemini)}")
# Out:
# Chat GPT Readability: 70.09
# Deep Seek Readability: 79.26
# Gemini Readability: 75.1

# %% [markdown]
# ### Vocabulary Richness
# Type-Token Ratio (TTR): Unique words / Total words
#
# Moving-Average TTR (MATTR): Adjusts for text length differences.

# %%
def ttr(text):
    words = text.split()
    return len(set(words)) / len(words)

print(f"Chat GPT TTR: {ttr(text1_gpt)}")
print(f"Deep Seek TTR: {ttr(text2_deep)}")
print(f"Gemini TTR: {ttr(text3_gemini)}")
# Out:
# Chat GPT TTR: 0.7027027027027027
# Deep Seek TTR: 0.7315789473684211
# Gemini TTR: 0.6282608695652174

# %% [markdown]
# ### Coherence and Similarity
#
# Cosine Similarity (Measures how semantically close two texts are)
#
# TF-IDF (Term Frequency-Inverse Document Frequency)

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform([text1_gpt, text2_deep, text3_gemini])

similarity = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])
print(f"Text Similarity Score: {similarity[0][0]}")
# Out:
# Text Similarity Score: 0.6341567750115922

# %% [markdown]
# ### Sentiment Analysis
#
# Measures positivity/negativity of text.

# %%
print(f"Text 1 Sentiment: {TextBlob(text1_gpt).sentiment.polarity}")
print(f"Text 2 Sentiment: {TextBlob(text2_deep).sentiment.polarity}")
print(f"Text 3 Sentiment: {TextBlob(text3_gemini).sentiment.polarity}")
# Out:
# Text 1 Sentiment: 0.06871212121212121
# Text 2 Sentiment: 0.00019841269841269925
# Text 3 Sentiment: 0.0023725895316804415

# %% [markdown]
# ### Grammar and Error Detection
#
# Grammar Score: Count number of grammatical errors.

# %%
tool = language_tool_python.LanguageTool('en-US')
errors_text1 = len(tool.check(text1_gpt))
errors_text2 = len(tool.check(text2_deep))
errors_text3 = len(tool.check(text3_gemini))

print(f"Chat GPT Errors: {errors_text1}, Deep Seek Errors: {errors_text2},  Gemini Errors: {errors_text3}")
# Out:
# Chat GPT Errors: 9, Deep Seek Errors: 28,  Gemini Errors: 0

# %% [markdown]
# ## Factual Accuracy

# %%
text4_gpt = "The key difference between AC (Alternating Current) and DC (Direct Current) is: AC Current: Changes direction periodically, meaning the flow of electric charge reverses at regular intervals. It is used in household power supplies and can be easily transformed to different voltages. DC Current: Flows in one constant direction without changing. It is used in batteries, electronics, and devices that require a steady voltage supply."
text5_deep = "The key differences between AC (Alternating Current) and DC (Direct Current) are: Direction of Flow: AC: Electrons reverse direction periodically (e.g., 50 60 times per second, measured in hertz). DC: Electrons flow steadily in one direction (e.g., from a battery). Voltage Characteristics: AC: Voltage varies sinusoidally (e.g., 120V or 230V household outlets). DC: Voltage remains constant (e.g., 12V in a car battery). Generation & Sources: AC: Produced by generators (alternators) and used in power grids.  DC: Produced by batteries, solar cells, or rectifiers (which convert AC to DC). Transmission Efficiency: AC: Can be stepped up/down via transformers, making it ideal for long distance power transmission.  DC: Harder to transmit over long distances without significant energy loss (though modern HVDC systems improve this). Applications: AC: Powers homes, industries, and appliances (e.g., refrigerators, lights).  DC: Used in electronics (e.g., phones, laptops), electric vehicles, and low voltage devices. TL; DR: AC reverses direction and is used for grids; DC flows one way and powers small electronics."
text6_gemini =  "The key difference between AC (Alternating Current) and DC (Direct Current) lies in the direction of electron flow: DC: Electrons flow in one direction only, from the negative terminal to the positive terminal. Think of it like water flowing in a single direction down a river. AC: Electrons periodically change direction, flowing back and forth. Imagine water sloshing back and forth in a tub. This difference in electron flow leads to several other distinctions: Voltage: DC voltage is constant, while AC voltage varies over time, oscillating between positive and negative values. Frequency: DC has a frequency of 0 Hz, as the current doesn't change direction. AC has a specific frequency (e.g., 50 Hz or 60 Hz), indicating how many times the current changes direction per second. Applications: DC is commonly used in batteries, electronic devices, and some industrial applications. AC is used for power transmission, household appliances, and most electrical grids. Transmission: AC is more efficient for long distance power transmission due to its ability to be easily transformed to higher voltages, reducing energy loss. In summary, DC is a steady, unidirectional flow of electrons, while AC is a dynamic, oscillating flow. This fundamental difference dictates their respective applications and characteristics."

# %% [markdown]
# ### Readability Score
#
# Flesch-Kincaid Readability Test
#
#     Measures how easy a text is to read.
#     Higher score = easier readability.

# %%
print(f"Chat GPT Readability: {flesch_reading_ease(text4_gpt)}")
print(f"Deep Seek Readability: {flesch_reading_ease(text5_deep)}")
print(f"Gemini Readability: {flesch_reading_ease(text6_gemini)}")

#print(f"Chat GPT Dale-Chall Score: {dale_chall_readability_score(text4_gpt)}")
#print(f"Deep Seek Dale-Chall Score: {dale_chall_readability_score(text5_deep)}")
#print(f"Gemini Readability: {flesch_reading_ease(text6_gemini)}")
# Out:
# Chat GPT Readability: 46.47
# Deep Seek Readability: 52.76
# Gemini Readability: 38.82

# %% [markdown]
# ### Vocabulary Richness
# Type-Token Ratio (TTR): Unique words / Total words
#
# Moving-Average TTR (MATTR): Adjusts for text length differences.

# %%
def ttr(text):
    words = text.split()
    return len(set(words)) / len(words)

print(f"Chat GPT TTR: {ttr(text4_gpt)}")
print(f"Deep Seek TTR: {ttr(text5_deep)}")
print(f"Gemini TTR: {ttr(text6_gemini)}")
# Out:
# Chat GPT TTR: 0.8153846153846154
# Deep Seek TTR: 0.7423312883435583
# Gemini TTR: 0.6567164179104478

# %% [markdown]
# ### Coherence and Similarity
#
# Cosine Similarity (Measures how semantically close two texts are)
#
# TF-IDF (Term Frequency-Inverse Document Frequency)

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform([text4_gpt, text5_deep, text6_gemini])

similarity = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])
print(f"Text Similarity Score: {similarity[0][0]}")
# Out:
# Text Similarity Score: 0.4797979201254741

# %% [markdown]
# ### Sentiment Analysis
#
# Measures positivity/negativity of text.

# %%
print(f"Chat GPT Text Sentiment: {TextBlob(text4_gpt).sentiment.polarity}")
print(f"Deep Seek Text Sentiment: {TextBlob(text5_deep).sentiment.polarity}")
print(f"Gemini Text Sentiment: {TextBlob(text6_gemini).sentiment.polarity}")
# Out:
# Chat GPT Text Sentiment: 0.06363636363636363
# Deep Seek Text Sentiment: 0.0861111111111111
# Gemini Text Sentiment: 0.047663268631010565

# %% [markdown]
# ### Grammar and Error Detection
#
# Grammar Score: Count number of grammatical errors.

# %%
tool = language_tool_python.LanguageTool('en-US')
errors_text4 = len(tool.check(text4_gpt))
errors_text5 = len(tool.check(text5_deep))
errors_text6 = len(tool.check(text6_gemini))

print(f"Chat GPT Errors: {errors_text4}, Deep Seek Errors: {errors_text5}, Gemini Errors: {errors_text6}")
# Out:
# Chat GPT Errors: 0, Deep Seek Errors: 0, Gemini Errors: 0

# %% [markdown]
# ## Open-Ended:

# %%
text7_gpt = "The ethical implications of AI in journalism include: Accuracy and Misinformation: AI generated content may contain errors or biases, potentially spreading misinformation if not properly monitored. Bias and Fairness: AI systems trained on biased data can perpetuate or amplify biases in reporting, leading to unfair representation of certain groups. Accountability: Determining responsibility for errors or unethical content generated by AI can be challenging, raising questions about accountability. Transparency: Journalists must disclose when AI tools are used in content creation to maintain audience trust. Job Displacement: Automation of tasks like data analysis, transcription, and even article writing could reduce job opportunities for human journalists. Privacy: AI systems that collect and analyze vast amounts of data for journalism must respect individuals' privacy rights. Quality and Depth: Over reliance on AI tools could lead to superficial reporting, as AI lacks human intuition, critical thinking, and ethical judgment. Balancing AI's efficiency with ethical journalism practices is crucial to maintaining public trust and journalistic integrity."
text8_deep = "The integration of   AI in journalism   brings significant ethical implications that must be carefully considered. Here are the key concerns: Accuracy and Misinformation Implication: AI tools like automated content generators can produce errors or propagate biases present in their training data, leading to the spread of misinformation. Ethical Concern: Journalistic integrity relies on factual accuracy. AI generated errors could erode public trust in media. Bias and Fairness    Implication: AI systems may inherit biases from their training datasets, leading to skewed or discriminatory reporting. Ethical Concern: Journalism must strive for fairness and objectivity. Biased AI could reinforce stereotypes or marginalize certain groups. Transparency and Accountability Implication: AI generated content often lacks clear disclosure, making it hard for readers to distinguish between human written and machine generated articles. Ethical Concern: Transparency is crucial for trust. Readers have a right to know how their news is produced. Job Displacement Implication: AI can automate tasks like data analysis, fact checking, and even writing, potentially displacing human journalists. Ethical Concern: This raises questions about the future of employment in journalism and the loss of human creativity and critical thinking in newsrooms. Privacy Concerns Implication: AI tools can analyze vast amounts of personal data to generate stories, potentially infringing on individuals' privacy. Ethical Concern: Journalists must balance public interest with respect for privacy, and AI could complicate this balance. Sensationalism and Clickbait Implication: AI algorithms optimized for engagement may prioritize sensational or clickbait headlines over nuanced reporting. Ethical Concern: This could undermine the quality of journalism and prioritize profit over public service. Deepfakes and Manipulated Media Implication: AI can create realistic deepfakes or manipulated audio/video, making it harder to verify the authenticity of content. Ethical Concern: This challenges the credibility of journalism and risks spreading false narratives. Access and Inequality Implication: News organizations with access to advanced AI tools may outcompete smaller outlets, widening the gap between large and small media entities. Ethical Concern: This could lead to a less diverse media landscape, concentrating power in the hands of a few. Addressing the Ethical Challenges: To mitigate these concerns, journalists and news organizations should: Ensure   human oversight   of AI generated content. Disclose the use of AI tools to maintain   transparency. Regularly audit AI systems for   bias and accuracy. Develop   ethical guidelines   for AI use in journalism. Advocate for   regulatory frameworks   to govern AI in media. TL;DR  : AI in journalism raises ethical concerns around accuracy, bias, transparency, job displacement, privacy, sensationalism, deepfakes, and inequality. Addressing these requires human oversight, transparency, and robust ethical guidelines."
text9_gemini =  "The use of AI in journalism presents a range of ethical implications that need careful consideration. Here are some of the key concerns: Accuracy and Fact Checking: AI generated content may contain errors or inaccuracies, especially if the data it's trained on is flawed or biased. Relying on AI for fact checking without human oversight can lead to the spread of misinformation. Bias and Fairness: AI algorithms can perpetuate existing biases present in the data they are trained on, leading to unfair or discriminatory outcomes in news reporting. This can result in certain groups being misrepresented or marginalized in the news. Transparency and Accountability: It can be difficult to understand how AI algorithms make decisions, making it challenging to identify and correct errors or biases. Lack of transparency can erode trust in the news media. Plagiarism and Copyright: AI models can generate content that is similar to existing works, potentially leading to plagiarism or copyright infringement. Determining ownership and responsibility for AI generated content is a complex issue. Job Displacement: The automation of journalistic tasks through AI could lead to job losses for journalists and other media professionals. This raises concerns about the future of the journalism profession and the need for retraining and upskilling. Erosion of Human Judgment: Over reliance on AI in journalism could diminish the role of human judgment, critical thinking, and ethical decision making. This could lead to a decline in the quality and depth of news reporting. Privacy and Data Security: AI systems often rely on vast amounts of data, raising concerns about the privacy and security of personal information. Journalists must ensure that the use of AI does not compromise the privacy of their sources or subjects. Public Trust: If AI is used in a way that is not transparent or ethical, it could damage public trust in the news media. It is crucial for journalists to be open and honest about how they use AI and to ensure that it is used responsibly. Addressing the Ethical Implications: To mitigate these ethical concerns, it is essential for journalists and news organizations to: Develop clear ethical guidelines for the use of AI in journalism. Ensure that AI systems are used in a way that is transparent, accountable, and fair. Prioritize human oversight and editorial judgment in the news process. Educate journalists and the public about the ethical implications of AI. Promote diversity and inclusivity in the development and use of AI technologies. By addressing these ethical implications proactively, journalists can harness the potential of AI while upholding the core values of journalism and maintaining public trust."

# %% [markdown]
# ### Readability Score
#
# Flesch-Kincaid Readability Test
#
#     Measures how easy a text is to read.
#     Higher score = easier readability.

# %%
print(f"Chat GPT Readability: {flesch_reading_ease(text7_gpt)}")
print(f"Deep Seek Readability: {flesch_reading_ease(text8_deep)}")
print(f"Gemini Readability: {flesch_reading_ease(text9_gemini)}")

#print(f"Chat GPT Dale-Chall Score: {dale_chall_readability_score(text7_gpt)}")
#print(f"Deep Seek Dale-Chall Score: {dale_chall_readability_score(text8_deep)}")
#print(f"Gemini Dale-Chall Score: {dale_chall_readability_score(text9_gemini)}")
# Out:
# Chat GPT Readability: 17.34
# Deep Seek Readability: 22.0
# Gemini Readability: 44.03

# %% [markdown]
# ### Vocabulary Richness
# Type-Token Ratio (TTR): Unique words / Total words
#
# Moving-Average TTR (MATTR): Adjusts for text length differences.

# %%
def ttr(text):
    words = text.split()
    return len(set(words)) / len(words)

print(f"Chat GPT TTR: {ttr(text7_gpt)}")
print(f"Deep Seek TTR: {ttr(text8_deep)}")
print(f"Gemini TTR: {ttr(text9_gemini)}")
# Out:
# Chat GPT TTR: 0.73125
# Deep Seek TTR: 0.5861244019138756
# Gemini TTR: 0.5150812064965197

# %% [markdown]
# ### Coherence and Similarity
#
# Cosine Similarity (Measures how semantically close two texts are)
#
# TF-IDF (Term Frequency-Inverse Document Frequency)

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform([text7_gpt, text8_deep, text9_gemini])

similarity = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])
print(f"Text Similarity Score: {similarity[0][0]}")
# Out:
# Text Similarity Score: 0.6510788384091469

# %% [markdown]
# ### Sentiment Analysis
#
# Measures positivity/negativity of text.

# %%
print(f"Chat GPT Text Sentiment: {TextBlob(text7_gpt).sentiment.polarity}")
print(f"Deep Seek Text Sentiment: {TextBlob(text8_deep).sentiment.polarity}")
print(f"Gemini Text Sentiment: {TextBlob(text9_gemini).sentiment.polarity}")
# Out:
# Chat GPT Text Sentiment: 0.058163265306122446
# Deep Seek Text Sentiment: 0.07477203647416415
# Gemini Text Sentiment: 0.04608013937282229

# %% [markdown]
# ### Grammar and Error Detection
#
# Grammar Score: Count number of grammatical errors.

# %%
tool = language_tool_python.LanguageTool('en-US')
errors_text7 = len(tool.check(text7_gpt))
errors_text8 = len(tool.check(text8_deep))
errors_text9 = len(tool.check(text9_gemini))

print(f"Chat GPT Errors: {errors_text7}, Deep Seek Errors: {errors_text8}, Gemini Errors: {errors_text9}")
# Out:
# Chat GPT Errors: 0, Deep Seek Errors: 13, Gemini Errors: 1

# %% [markdown]
# ## Technical Explanations

# %%
text10_gpt = "Sure! Blockchain technology is like a digital ledger or notebook that keeps a secure record of transactions. Imagine a chain made up of blocks, where each block holds a list of transactions. Once a block is filled, it is linked to the previous block, forming a chain. What makes blockchain special: Decentralized: No single person or company controls it; it's shared across many computers. Secure: Once data is added, it cannot be changed or erased. Transparent: Everyone on the network can see the transactions, making it trustworthy. It’s the technology behind cryptocurrencies like Bitcoin, but it’s also used for things like smart contracts, supply chain management, and secure voting systems."
text11_deep = "Sure! Let’s break down   blockchain technology   into simple terms: What is Blockchain? Imagine a   digital ledger (like a notebook) that records transactions. Instead of being stored in one place, this ledger is copied and shared across many computers (called   nodes) in a network. Every time a new transaction happens; it’s added to the ledger as a   block. These blocks are linked together in a   chain —hence the name blockchain. Key Features of Blockchain: Decentralized:  No single person or company controls the ledger. It’s shared and maintained by everyone in the network. Transparent:  Everyone in the network can see the transactions, making it hard to cheat or alter the data. Secure: Each block is protected by   cryptography (advanced math), making it nearly impossible to hack or change past transactions. Immutable: Once a block is added to the chain, it can’t be changed. This ensures trust and reliability. How Does It Work? Transaction Request: Someone wants to send money, data, or anything of value. Verification:  The network checks if the transaction is valid (e.g., does the sender have enough funds?). Block Creation: Valid transactions are grouped into a block. Block Addition: The block is added to the chain, and the updated ledger is shared with everyone in the network. Real Life Example: Think of blockchain like a   Google Doc   shared with a group: Everyone can see the document (transparent). No one can edit it without others noticing (secure).  Every change is saved and can’t be erased (immutable). Why is Blockchain Important? Trust: No need for a middleman (like a bank) to verify transactions. Efficiency: Faster and cheaper transactions, especially across borders. Innovation: Powers technologies like   cryptocurrencies   (e.g., Bitcoin),   smart contracts  , and more. TL;DR  : Blockchain is a secure, shared digital ledger that records transactions in a way that’s transparent, tamper proof, and doesn’t rely on a central authority. It’s like a super safe, shared notebook for the digital age!"
text12_gemini =  "Imagine a digital ledger, like a giant spreadsheet, that keeps track of transactions. But instead of being stored in one place, it's copied and distributed to many computers across a network. This makes it incredibly secure and transparent. Here's how it works: Transaction: When someone wants to make a transaction (like sending money or data), it's recorded as a block of information. Verification: This block is then sent to the network of computers, where it's verified by everyone. Chain: Once verified, the block is added to the chain of previous blocks, creating a permanent and unalterable record. Distribution: Everyone on the network gets a copy of this updated chain, so everyone has the same information. Why is this a big deal? Security: Because the ledger is distributed and every transaction is verified, it's extremely difficult to tamper with or hack. Transparency: Everyone on the network can see the transactions, promoting trust and accountability. Decentralization: No single entity controls the blockchain, making it resistant to censorship or manipulation. Think of it like this: Imagine you and your friends have a shared notebook where you record all your transactions (like lending each other money). Every time someone makes a transaction, everyone writes it down in their own notebook. This way, everyone has a record of what happened, and no one can cheat or change the records without everyone else noticing. That's essentially how blockchain works! It's a technology that has the potential to revolutionize many industries, from finance and supply chain management to healthcare and voting systems."

# %% [markdown]
# ### Readability Score
#
# Flesch-Kincaid Readability Test
#
#     Measures how easy a text is to read.
#     Higher score = easier readability.

# %%
print(f"Chat GPT Readability: {flesch_reading_ease(text10_gpt)}")
print(f"Deep Seek Readability: {flesch_reading_ease(text11_deep)}")
print(f"Gemini Readability: {flesch_reading_ease(text12_gemini)}")

#print(f"Chat GPT Dale-Chall Score: {dale_chall_readability_score(text7_gpt)}")
#print(f"Deep Seek Dale-Chall Score: {dale_chall_readability_score(text8_deep)}")
#print(f"Gemini Dale-Chall Score: {dale_chall_readability_score(text9_gemini)}")
# Out:
# Chat GPT Readability: 64.0
# Deep Seek Readability: 68.06
# Gemini Readability: 55.34

# %% [markdown]
# ### Vocabulary Richness
# Type-Token Ratio (TTR): Unique words / Total words
#
# Moving-Average TTR (MATTR): Adjusts for text length differences.

# %%
def ttr(text):
    words = text.split()
    return len(set(words)) / len(words)

print(f"Chat GPT TTR: {ttr(text10_gpt)}")
print(f"Deep Seek TTR: {ttr(text11_deep)}")
print(f"Gemini TTR: {ttr(text12_gemini)}")
# Out:
# Chat GPT TTR: 0.7727272727272727
# Deep Seek TTR: 0.6194968553459119
# Gemini TTR: 0.6431372549019608

# %% [markdown]
# ### Coherence and Similarity
#
# Cosine Similarity (Measures how semantically close two texts are)
#
# TF-IDF (Term Frequency-Inverse Document Frequency)

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform([text10_gpt, text11_deep, text12_gemini])

similarity = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])
print(f"Text Similarity Score: {similarity[0][0]}")
# Out:
# Text Similarity Score: 0.6155242798951065

# %% [markdown]
# ### Sentiment Analysis
#
# Measures positivity/negativity of text.

# %%
print(f"Chat GPT Text Sentiment: {TextBlob(text10_gpt).sentiment.polarity}")
print(f"Deep Seek Text Sentiment: {TextBlob(text11_deep).sentiment.polarity}")
print(f"Gemini Text Sentiment: {TextBlob(text12_gemini).sentiment.polarity}")
# Out:
# Chat GPT Text Sentiment: 0.2304563492063492
# Deep Seek Text Sentiment: 0.1437336326225215
# Gemini Text Sentiment: 0.08053075396825397

# %% [markdown]
# ### Grammar and Error Detection
#
# Grammar Score: Count number of grammatical errors.

# %%
tool = language_tool_python.LanguageTool('en-US')
errors_text10 = len(tool.check(text10_gpt))
errors_text11 = len(tool.check(text11_deep))
errors_text12 = len(tool.check(text12_gemini))

print(f"Chat GPT Errors: {errors_text10}, Deep Seek Errors: {errors_text11}, Gemini Errors: {errors_text12}")
# Out:
# Chat GPT Errors: 0, Deep Seek Errors: 18, Gemini Errors: 1
